# %%
# find MovieLense 20M dataset on kaggle
# download rating.csv

# %%
import pandas as pd
from collections import Counter
from sklearn.utils import shuffle
import pickle
import numpy as np
import datetime as datetime
import matplotlib.pyplot as plt
from sortedcontainers import SortedList

# %% [markdown]
# <h2>Preprocessing<h2>

# %%
df = pd.read_csv('rating.csv')

# %%
df.head(3)
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39

# %%
# IDs from 1 , we need to get them to start from 0
# thankfully no missing number in between
df.userId -= 1

# %%
# movie ids from 1 with missing number in between
# make user id go from 0 - N-1 ,
# not all movies have ids
# this takes some time
movie_ids = set(df.movieId.values)
movie2idx = {k:v for v,k in enumerate(movie_ids)}
df['movie_idx'] = df.apply(lambda row: movie2idx[row.movieId] , axis = 1)

# %%
# drop unecessary timestamp col
df = df.drop(columns=['timestamp'])

# %%
# since that took some time lets save
df.to_csv('rating_1.csv')

# %%
# the data is too large
# to provide as much processable data as possible
# select subset of users who rated most movies and movies rated by most users
df = pd.read_csv('rating_1.csv')

# %%
N = df.userId.max() + 1 # no of users
M = df.movie_idx.max() + 1 # no of moives
# the user-user algorithm is O(n^2 m) , so better keep n low
# the item-item algorithm is O(n m^2 ) , so its also better to keep m low
n = 1000 # number of users to take , 
m = 200 # number of movies to take

# %%
user_ids_count = Counter(df.userId) # counts occurunces of each element
movie_ids_count = Counter(df.movie_idx) 

top_user_ids = [i for i,_ in user_ids_count.most_common(n)] # id:count
top_movie_ids = [i for i,_ in movie_ids_count.most_common(m)]

# %%
# make a copy to overwrite data later
df_small = df[df.userId.isin(top_user_ids) & df.movie_idx.isin(top_movie_ids)].copy()

# %%
# new mapping of top IDs , to run from 0 - N-1 without missing ids in between
new_user_id_map = {k:v for v,k in enumerate(top_user_ids)}
# same for movies
new_movie_id_map = {k:v for v,k in enumerate(top_movie_ids)}

# %%
# apply changes to df_small
df_small['userId'] = df_small.apply(lambda row: new_user_id_map[row.userId] , axis = 1)
df_small['movie_idx'] = df_small.apply(lambda row: new_movie_id_map[row.movie_idx] , axis = 1)

# %%
print("max user id:", df_small.userId.max())
print("max movie id:", df_small.movie_idx.max())
print("small dataframe size:", len(df_small))
df_small.to_csv('small_rating.csv')
# Out:
# max user id: 999
# max movie id: 199
# small dataframe size: 167035

# %%
df = pd.read_csv('small_rating.csv')

# %%
N = df.userId.max() + 1 # no of users
M = df.movie_idx.max() + 1 # no of moives

# %%
# split train-test
df = shuffle(df)
cutoff = int(0.8*len(df))
df_train = df.iloc[:cutoff]
df_test = df.iloc[cutoff:]

# %%
user2movie = {}
movie2user = {}
user_movie2rating = {}
count = 0
def update_dicts(row): # takes a row of pandas data frame
    global count
    count+=1
    if count % 100000 == 0:
        print('processed %.3f %%' %(float(count)/cutoff))
    
    i = int(row.userId)
    j = int(row.movie_idx)
    
    if i not in user2movie:
        user2movie[i] = [j]
    else:
        user2movie[i].append(j)
    
    if j not in movie2user:
        movie2user[j] = [i]
    else:
        movie2user[j].append(i)
        
    user_movie2rating[(i,j)] = row.rating

# %%
df_train.apply(update_dicts,axis=1)
# Out:
# processed 0.748 %
# 12338     None
# 86650     None
# 152492    None
# 13193     None
# 141970    None
#           ...
# 23703     None
# 22584     None
# 150656    None
# 4501      None
# 4598      None
# Length: 133628, dtype: object

# %%
user_movie2rating_test = {}
count = 0
def update_dict_test(row): # takes a row of pandas data frame
    global count
    count+=1
    if count % 100000 == 0:
        print('processed %.3f %%' %(float(count)/len(df_test)))
    
    i = int(row.userId)
    j = int(row.movie_idx)
    
    user_movie2rating_test[(i,j)] = row.rating

# %%
df_test.apply(update_dict_test,axis=1)
# Out:
# 156303    None
# 134018    None
# 4882      None
# 4632      None
# 135393    None
#           ...
# 6021      None
# 88457     None
# 158417    None
# 155380    None
# 103799    None
# Length: 33407, dtype: object

# %%
with open('user2movie.json','wb') as f:
    pickle.dump(user2movie,f)
    
with open('movie2user.json','wb') as f:
    pickle.dump(movie2user,f)
    
with open('user_movie2rating.json','wb') as f:
    pickle.dump(user_movie2rating,f)
    
with open('user_movie2rating_test.json','wb') as f:
    pickle.dump(user_movie2rating_test,f)

# %% [markdown]
# <h2>User-User Collaborative Filtering</h2>

# %%
with open('user2movie.json','rb') as f:
    user2movie = pickle.load(f)
    
with open('movie2user.json','rb') as f:
    movie2user = pickle.load(f)
    
with open('user_movie2rating.json','rb') as f:
    user_movie2rating =  pickle.load(f)
    
with open('user_movie2rating_test.json','rb') as f:
    user_movie2rating_test =  pickle.load(f)

# %%
N = np.max(list(user2movie.keys()))+1
# some movies may appear in test but not in train
# unlikely to occur in user
m1 = np.max(list(movie2user.keys()))
m2 = np.max([m for(u,m),r in user_movie2rating_test.items()])
M = max(m1,m2) + 1

# %%
K = 25 # number of neighbours to consider
limit = 5 # number of movies users must have in common to consider
averages = [] # each user's average rating
deviations = [] # each user's deviation
neighbors = [] # each element is a list of neighbours for each user

# %%
for i in range(N): # now i is user
    movies_i = user2movie[i]
    movies_i_set = set(movies_i)
    
    # calculate average and deviation
    ratings_i = {movie:user_movie2rating[(i,movie)] for movie in movies_i} # rating for each movie
    avg_i = np.mean(list(ratings_i.values())) # average across all movies
    dev_i = {movie:(rating-avg_i) for movie,rating in ratings_i.items()} # deviation for each movie
    dev_i_values = np.array(list(dev_i.values()))
    sigma_i = np.sqrt(dev_i_values.dot(dev_i_values))
    
    # calculate correlation coeffecient
    averages.append(avg_i)
    deviations.append(dev_i)
    
    sl = SortedList()
    for j in range(N):
        if j != i: # dont include this i th user
            movies_j = user2movie[j]
            movies_j_set = set(movies_j)
            common_movies = (movies_i_set & movies_j_set) # intersection
            if len(common_movies) > limit:
                # calculate  avg and ddeviation
                ratings_j = {movie:user_movie2rating[(j,movie)] for movie in movies_j} # rating for each movie
                avg_j = np.mean(list(ratings_j.values())) # average across all movies
                dev_j = {movie:(rating-avg_j) for movie,rating in ratings_j.items()} # deviation for each movie
                dev_j_values = np.array(list(dev_j.values()))
                sigma_j = np.sqrt(dev_j_values.dot(dev_j_values))
                
                # calculate correlation coffecient
                numerator = sum(dev_i[m]*dev_j[m] for m in common_movies)
                w_ij = numerator / (sigma_i * sigma_j)
                sl.add((-w_ij,j)) # list sorts ascendingly , to keep highest first negate
                if len(sl) > K:
                    del sl[-1]
    neighbors.append(sl)
    print('finished processing for user id: ',i)
# Out:
# finished processing for user id:  0
# finished processing for user id:  1
# finished processing for user id:  2
# finished processing for user id:  3
# finished processing for user id:  4
# finished processing for user id:  5
# finished processing for user id:  6
# finished processing for user id:  7
# finished processing for user id:  8
# finished processing for user id:  9
# finished processing for user id:  10
# finished processing for user id:  11
# finished processing for user id:  12
# finished processing for user id:  13
# finished processing for user id:  14
# finished processing for user id:  15
# finished processing for user id:  16
# finished processing for user id:  17
# finished processing for user id:  18
# finished processing for user id:  19
# finished processing for user id:  20
# finished processing for user id:  21
# finished processing for user id:  22
# finished processing for user id:  23
# finished processing for user id:  24
# finished processing for user id:  25
# finished processing for user id:  26
# finished processing for user id:  27
# finished processing for user id:  28
# finished processing for user id:  29
# finished processing for user id:  30
# finished processing for user id:  31
# finished processing for user id:  32
# finished processing for user id:  33
# finished processing for user id:  34
# finished processing for user id:  35
# finished processing for user id:  36
# finished processing for user id:  37
# finished processing for user id:  38
# finished processing for user id:  39
# finished processing for user id:  40
# finished processing for user id:  41
# finished processing for user id:  42
# finished processing for user id:  43
# finished processing for user id:  44
# finished processing for user id:  45
# finished processing for user id:  46
# finished processing for user id:  47
# finished processing for user id:  48
# finished processing for user id:  49
# finished processing for user id:  50
# finished processing for user id:  51
# finished processing for user id:  52
# finished processing for user id:  53
# finished processing for user id:  54
# finished processing for user id:  55
# finished processing for user id:  56
# finished processing for user id:  57
# finished processing for user id:  58
# finished processing for user id:  59
# finished processing for user id:  60
# finished processing for user id:  61
# finished processing for user id:  62
# finished processing for user id:  63
# finished processing for user id:  64
# finished processing for user id:  65
# finished processing for user id:  66
# finished processing for user id:  67
# finished processing for user id:  68
# finished processing for user id:  69
# finished processing for user id:  70
# finished processing for user id:  71
# finished processing for user id:  72
# finished processing for user id:  73
# finished processing for user id:  74
# finished processing for user id:  75
# finished processing for user id:  76
# finished processing for user id:  77
# finished processing for user id:  78
# finished processing for user id:  79
# finished processing for user id:  80
# finished processing for user id:  81
# finished processing for user id:  82
# finished processing for user id:  83
# finished processing for user id:  84
# finished processing for user id:  85
# finished processing for user id:  86
# finished processing for user id:  87
# finished processing for user id:  88
# finished processing for user id:  89
# finished processing for user id:  90
# finished processing for user id:  91
# finished processing for user id:  92
# finished processing for user id:  93
# finished processing for user id:  94
# finished processing for user id:  95
# finished processing for user id:  96
# finished processing for user id:  97
# finished processing for user id:  98
# finished processing for user id:  99
# finished processing for user id:  100
# finished processing for user id:  101
# finished processing for user id:  102
# finished processing for user id:  103
# finished processing for user id:  104
# finished processing for user id:  105
# finished processing for user id:  106
# finished processing for user id:  107
# finished processing for user id:  108
# finished processing for user id:  109
# finished processing for user id:  110
# finished processing for user id:  111
# finished processing for user id:  112
# finished processing for user id:  113
# finished processing for user id:  114
# finished processing for user id:  115
# finished processing for user id:  116
# finished processing for user id:  117
# finished processing for user id:  118
# finished processing for user id:  119
# finished processing for user id:  120
# finished processing for user id:  121
# finished processing for user id:  122
# finished processing for user id:  123
# finished processing for user id:  124
# finished processing for user id:  125
# finished processing for user id:  126
# finished processing for user id:  127
# finished processing for user id:  128
# finished processing for user id:  129
# finished processing for user id:  130
# finished processing for user id:  131
# finished processing for user id:  132
# finished processing for user id:  133
# finished processing for user id:  134
# finished processing for user id:  135
# finished processing for user id:  136
# finished processing for user id:  137
# finished processing for user id:  138
# finished processing for user id:  139
# finished processing for user id:  140
# finished processing for user id:  141
# finished processing for user id:  142
# finished processing for user id:  143
# finished processing for user id:  144
# finished processing for user id:  145
# finished processing for user id:  146
# finished processing for user id:  147
# finished processing for user id:  148
# finished processing for user id:  149
# finished processing for user id:  150
# finished processing for user id:  151
# finished processing for user id:  152
# finished processing for user id:  153
# finished processing for user id:  154
# finished processing for user id:  155
# finished processing for user id:  156
# finished processing for user id:  157
# finished processing for user id:  158
# finished processing for user id:  159
# finished processing for user id:  160
# finished processing for user id:  161
# finished processing for user id:  162
# finished processing for user id:  163
# finished processing for user id:  164
# finished processing for user id:  165
# finished processing for user id:  166
# finished processing for user id:  167
# finished processing for user id:  168
# finished processing for user id:  169
# finished processing for user id:  170
# finished processing for user id:  171
# finished processing for user id:  172
# finished processing for user id:  173
# finished processing for user id:  174
# finished processing for user id:  175
# finished processing for user id:  176
# finished processing for user id:  177
# finished processing for user id:  178
# finished processing for user id:  179
# finished processing for user id:  180
# finished processing for user id:  181
# finished processing for user id:  182
# finished processing for user id:  183
# finished processing for user id:  184
# finished processing for user id:  185
# finished processing for user id:  186
# finished processing for user id:  187
# finished processing for user id:  188
# finished processing for user id:  189
# finished processing for user id:  190
# finished processing for user id:  191
# finished processing for user id:  192
# finished processing for user id:  193
# finished processing for user id:  194
# finished processing for user id:  195
# finished processing for user id:  196
# finished processing for user id:  197
# finished processing for user id:  198
# finished processing for user id:  199
# finished processing for user id:  200
# finished processing for user id:  201
# finished processing for user id:  202
# finished processing for user id:  203
# finished processing for user id:  204
# finished processing for user id:  205
# finished processing for user id:  206
# finished processing for user id:  207
# finished processing for user id:  208
# finished processing for user id:  209
# finished processing for user id:  210
# finished processing for user id:  211
# finished processing for user id:  212
# finished processing for user id:  213
# finished processing for user id:  214
# finished processing for user id:  215
# finished processing for user id:  216
# finished processing for user id:  217
# finished processing for user id:  218
# finished processing for user id:  219
# finished processing for user id:  220
# finished processing for user id:  221
# finished processing for user id:  222
# finished processing for user id:  223
# finished processing for user id:  224
# finished processing for user id:  225
# finished processing for user id:  226
# finished processing for user id:  227
# finished processing for user id:  228
# finished processing for user id:  229
# finished processing for user id:  230
# finished processing for user id:  231
# finished processing for user id:  232
# finished processing for user id:  233
# finished processing for user id:  234
# finished processing for user id:  235
# finished processing for user id:  236
# finished processing for user id:  237
# finished processing for user id:  238
# finished processing for user id:  239
# finished processing for user id:  240
# finished processing for user id:  241
# finished processing for user id:  242
# finished processing for user id:  243
# finished processing for user id:  244
# finished processing for user id:  245
# finished processing for user id:  246
# finished processing for user id:  247
# finished processing for user id:  248
# finished processing for user id:  249
# finished processing for user id:  250
# finished processing for user id:  251
# finished processing for user id:  252
# finished processing for user id:  253
# finished processing for user id:  254
# finished processing for user id:  255
# finished processing for user id:  256
# finished processing for user id:  257
# finished processing for user id:  258
# finished processing for user id:  259
# finished processing for user id:  260
# finished processing for user id:  261
# finished processing for user id:  262
# finished processing for user id:  263
# finished processing for user id:  264
# finished processing for user id:  265
# finished processing for user id:  266
# finished processing for user id:  267
# finished processing for user id:  268
# finished processing for user id:  269
# finished processing for user id:  270
# finished processing for user id:  271
# finished processing for user id:  272
# finished processing for user id:  273
# finished processing for user id:  274
# finished processing for user id:  275
# finished processing for user id:  276
# finished processing for user id:  277
# finished processing for user id:  278
# finished processing for user id:  279
# finished processing for user id:  280
# finished processing for user id:  281
# finished processing for user id:  282
# finished processing for user id:  283
# finished processing for user id:  284
# finished processing for user id:  285
# finished processing for user id:  286
# finished processing for user id:  287
# finished processing for user id:  288
# finished processing for user id:  289
# finished processing for user id:  290
# finished processing for user id:  291
# finished processing for user id:  292
# finished processing for user id:  293
# finished processing for user id:  294
# finished processing for user id:  295
# finished processing for user id:  296
# finished processing for user id:  297
# finished processing for user id:  298
# finished processing for user id:  299
# finished processing for user id:  300
# finished processing for user id:  301
# finished processing for user id:  302
# finished processing for user id:  303
# finished processing for user id:  304
# finished processing for user id:  305
# finished processing for user id:  306
# finished processing for user id:  307
# finished processing for user id:  308
# finished processing for user id:  309
# finished processing for user id:  310
# finished processing for user id:  311
# finished processing for user id:  312
# finished processing for user id:  313
# finished processing for user id:  314
# finished processing for user id:  315
# finished processing for user id:  316
# finished processing for user id:  317
# finished processing for user id:  318
# finished processing for user id:  319
# finished processing for user id:  320
# finished processing for user id:  321
# finished processing for user id:  322
# finished processing for user id:  323
# finished processing for user id:  324
# finished processing for user id:  325
# finished processing for user id:  326
# finished processing for user id:  327
# finished processing for user id:  328
# finished processing for user id:  329
# finished processing for user id:  330
# finished processing for user id:  331
# finished processing for user id:  332
# finished processing for user id:  333
# finished processing for user id:  334
# finished processing for user id:  335
# finished processing for user id:  336
# finished processing for user id:  337
# finished processing for user id:  338
# finished processing for user id:  339
# finished processing for user id:  340
# finished processing for user id:  341
# finished processing for user id:  342
# finished processing for user id:  343
# finished processing for user id:  344
# finished processing for user id:  345
# finished processing for user id:  346
# finished processing for user id:  347
# finished processing for user id:  348
# finished processing for user id:  349
# finished processing for user id:  350
# finished processing for user id:  351
# finished processing for user id:  352
# finished processing for user id:  353
# finished processing for user id:  354
# finished processing for user id:  355
# finished processing for user id:  356
# finished processing for user id:  357
# finished processing for user id:  358
# finished processing for user id:  359
# finished processing for user id:  360
# finished processing for user id:  361
# finished processing for user id:  362
# finished processing for user id:  363
# finished processing for user id:  364
# finished processing for user id:  365
# finished processing for user id:  366
# finished processing for user id:  367
# finished processing for user id:  368
# finished processing for user id:  369
# finished processing for user id:  370
# finished processing for user id:  371
# finished processing for user id:  372
# finished processing for user id:  373
# finished processing for user id:  374
# finished processing for user id:  375
# finished processing for user id:  376
# finished processing for user id:  377
# finished processing for user id:  378
# finished processing for user id:  379
# finished processing for user id:  380
# finished processing for user id:  381
# finished processing for user id:  382
# finished processing for user id:  383
# finished processing for user id:  384
# finished processing for user id:  385
# finished processing for user id:  386
# finished processing for user id:  387
# finished processing for user id:  388
# finished processing for user id:  389
# finished processing for user id:  390
# finished processing for user id:  391
# finished processing for user id:  392
# finished processing for user id:  393
# finished processing for user id:  394
# finished processing for user id:  395
# finished processing for user id:  396
# finished processing for user id:  397
# finished processing for user id:  398
# finished processing for user id:  399
# finished processing for user id:  400
# finished processing for user id:  401
# finished processing for user id:  402
# finished processing for user id:  403
# finished processing for user id:  404
# finished processing for user id:  405
# finished processing for user id:  406
# finished processing for user id:  407
# finished processing for user id:  408
# finished processing for user id:  409
# finished processing for user id:  410
# finished processing for user id:  411
# finished processing for user id:  412
# finished processing for user id:  413
# finished processing for user id:  414
# finished processing for user id:  415
# finished processing for user id:  416
# finished processing for user id:  417
# finished processing for user id:  418
# finished processing for user id:  419
# finished processing for user id:  420
# finished processing for user id:  421
# finished processing for user id:  422
# finished processing for user id:  423
# finished processing for user id:  424
# finished processing for user id:  425
# finished processing for user id:  426
# finished processing for user id:  427
# finished processing for user id:  428
# finished processing for user id:  429
# finished processing for user id:  430
# finished processing for user id:  431
# finished processing for user id:  432
# finished processing for user id:  433
# finished processing for user id:  434
# finished processing for user id:  435
# finished processing for user id:  436
# finished processing for user id:  437
# finished processing for user id:  438
# finished processing for user id:  439
# finished processing for user id:  440
# finished processing for user id:  441
# finished processing for user id:  442
# finished processing for user id:  443
# finished processing for user id:  444
# finished processing for user id:  445
# finished processing for user id:  446
# finished processing for user id:  447
# finished processing for user id:  448
# finished processing for user id:  449
# finished processing for user id:  450
# finished processing for user id:  451
# finished processing for user id:  452
# finished processing for user id:  453
# finished processing for user id:  454
# finished processing for user id:  455
# finished processing for user id:  456
# finished processing for user id:  457
# finished processing for user id:  458
# finished processing for user id:  459
# finished processing for user id:  460
# finished processing for user id:  461
# finished processing for user id:  462
# finished processing for user id:  463
# finished processing for user id:  464
# finished processing for user id:  465
# finished processing for user id:  466
# finished processing for user id:  467
# finished processing for user id:  468
# finished processing for user id:  469
# finished processing for user id:  470
# finished processing for user id:  471
# finished processing for user id:  472
# finished processing for user id:  473
# finished processing for user id:  474
# finished processing for user id:  475
# finished processing for user id:  476
# finished processing for user id:  477
# finished processing for user id:  478
# finished processing for user id:  479
# finished processing for user id:  480
# finished processing for user id:  481
# finished processing for user id:  482
# finished processing for user id:  483
# finished processing for user id:  484
# finished processing for user id:  485
# finished processing for user id:  486
# finished processing for user id:  487
# finished processing for user id:  488
# finished processing for user id:  489
# finished processing for user id:  490
# finished processing for user id:  491
# finished processing for user id:  492
# finished processing for user id:  493
# finished processing for user id:  494
# finished processing for user id:  495
# finished processing for user id:  496
# finished processing for user id:  497
# finished processing for user id:  498
# finished processing for user id:  499
# finished processing for user id:  500
# finished processing for user id:  501
# finished processing for user id:  502
# finished processing for user id:  503
# finished processing for user id:  504
# finished processing for user id:  505
# finished processing for user id:  506
# finished processing for user id:  507
# finished processing for user id:  508
# finished processing for user id:  509
# finished processing for user id:  510
# finished processing for user id:  511
# finished processing for user id:  512
# finished processing for user id:  513
# finished processing for user id:  514
# finished processing for user id:  515
# finished processing for user id:  516
# finished processing for user id:  517
# finished processing for user id:  518
# finished processing for user id:  519
# finished processing for user id:  520
# finished processing for user id:  521
# finished processing for user id:  522
# finished processing for user id:  523
# finished processing for user id:  524
# finished processing for user id:  525
# finished processing for user id:  526
# finished processing for user id:  527
# finished processing for user id:  528
# finished processing for user id:  529
# finished processing for user id:  530
# finished processing for user id:  531
# finished processing for user id:  532
# finished processing for user id:  533
# finished processing for user id:  534
# finished processing for user id:  535
# finished processing for user id:  536
# finished processing for user id:  537
# finished processing for user id:  538
# finished processing for user id:  539
# finished processing for user id:  540
# finished processing for user id:  541
# finished processing for user id:  542
# finished processing for user id:  543
# finished processing for user id:  544
# finished processing for user id:  545
# finished processing for user id:  546
# finished processing for user id:  547
# finished processing for user id:  548
# finished processing for user id:  549
# finished processing for user id:  550
# finished processing for user id:  551
# finished processing for user id:  552
# finished processing for user id:  553
# finished processing for user id:  554
# finished processing for user id:  555
# finished processing for user id:  556
# finished processing for user id:  557
# finished processing for user id:  558
# finished processing for user id:  559
# finished processing for user id:  560
# finished processing for user id:  561
# finished processing for user id:  562
# finished processing for user id:  563
# finished processing for user id:  564
# finished processing for user id:  565
# finished processing for user id:  566
# finished processing for user id:  567
# finished processing for user id:  568
# finished processing for user id:  569
# finished processing for user id:  570
# finished processing for user id:  571
# finished processing for user id:  572
# finished processing for user id:  573
# finished processing for user id:  574
# finished processing for user id:  575
# finished processing for user id:  576
# finished processing for user id:  577
# finished processing for user id:  578
# finished processing for user id:  579
# finished processing for user id:  580
# finished processing for user id:  581
# finished processing for user id:  582
# finished processing for user id:  583
# finished processing for user id:  584
# finished processing for user id:  585
# finished processing for user id:  586
# finished processing for user id:  587
# finished processing for user id:  588
# finished processing for user id:  589
# finished processing for user id:  590
# finished processing for user id:  591
# finished processing for user id:  592
# finished processing for user id:  593
# finished processing for user id:  594
# finished processing for user id:  595
# finished processing for user id:  596
# finished processing for user id:  597
# finished processing for user id:  598
# finished processing for user id:  599
# finished processing for user id:  600
# finished processing for user id:  601
# finished processing for user id:  602
# finished processing for user id:  603
# finished processing for user id:  604
# finished processing for user id:  605
# finished processing for user id:  606
# finished processing for user id:  607
# finished processing for user id:  608
# finished processing for user id:  609
# finished processing for user id:  610
# finished processing for user id:  611
# finished processing for user id:  612
# finished processing for user id:  613
# finished processing for user id:  614
# finished processing for user id:  615
# finished processing for user id:  616
# finished processing for user id:  617
# finished processing for user id:  618
# finished processing for user id:  619
# finished processing for user id:  620
# finished processing for user id:  621
# finished processing for user id:  622
# finished processing for user id:  623
# finished processing for user id:  624
# finished processing for user id:  625
# finished processing for user id:  626
# finished processing for user id:  627
# finished processing for user id:  628
# finished processing for user id:  629
# finished processing for user id:  630
# finished processing for user id:  631
# finished processing for user id:  632
# finished processing for user id:  633
# finished processing for user id:  634
# finished processing for user id:  635
# finished processing for user id:  636
# finished processing for user id:  637
# finished processing for user id:  638
# finished processing for user id:  639
# finished processing for user id:  640
# finished processing for user id:  641
# finished processing for user id:  642
# finished processing for user id:  643
# finished processing for user id:  644
# finished processing for user id:  645
# finished processing for user id:  646
# finished processing for user id:  647
# finished processing for user id:  648
# finished processing for user id:  649
# finished processing for user id:  650
# finished processing for user id:  651
# finished processing for user id:  652
# finished processing for user id:  653
# finished processing for user id:  654
# finished processing for user id:  655
# finished processing for user id:  656
# finished processing for user id:  657
# finished processing for user id:  658
# finished processing for user id:  659
# finished processing for user id:  660
# finished processing for user id:  661
# finished processing for user id:  662
# finished processing for user id:  663
# finished processing for user id:  664
# finished processing for user id:  665
# finished processing for user id:  666
# finished processing for user id:  667
# finished processing for user id:  668
# finished processing for user id:  669
# finished processing for user id:  670
# finished processing for user id:  671
# finished processing for user id:  672
# finished processing for user id:  673
# finished processing for user id:  674
# finished processing for user id:  675
# finished processing for user id:  676
# finished processing for user id:  677
# finished processing for user id:  678
# finished processing for user id:  679
# finished processing for user id:  680
# finished processing for user id:  681
# finished processing for user id:  682
# finished processing for user id:  683
# finished processing for user id:  684
# finished processing for user id:  685
# finished processing for user id:  686
# finished processing for user id:  687
# finished processing for user id:  688
# finished processing for user id:  689
# finished processing for user id:  690
# finished processing for user id:  691
# finished processing for user id:  692
# finished processing for user id:  693
# finished processing for user id:  694
# finished processing for user id:  695
# finished processing for user id:  696
# finished processing for user id:  697
# finished processing for user id:  698
# finished processing for user id:  699
# finished processing for user id:  700
# finished processing for user id:  701
# finished processing for user id:  702
# finished processing for user id:  703
# finished processing for user id:  704
# finished processing for user id:  705
# finished processing for user id:  706
# finished processing for user id:  707
# finished processing for user id:  708
# finished processing for user id:  709
# finished processing for user id:  710
# finished processing for user id:  711
# finished processing for user id:  712
# finished processing for user id:  713
# finished processing for user id:  714
# finished processing for user id:  715
# finished processing for user id:  716
# finished processing for user id:  717
# finished processing for user id:  718
# finished processing for user id:  719
# finished processing for user id:  720
# finished processing for user id:  721
# finished processing for user id:  722
# finished processing for user id:  723
# finished processing for user id:  724
# finished processing for user id:  725
# finished processing for user id:  726
# finished processing for user id:  727
# finished processing for user id:  728
# finished processing for user id:  729
# finished processing for user id:  730
# finished processing for user id:  731
# finished processing for user id:  732
# finished processing for user id:  733
# finished processing for user id:  734
# finished processing for user id:  735
# finished processing for user id:  736
# finished processing for user id:  737
# finished processing for user id:  738
# finished processing for user id:  739
# finished processing for user id:  740
# finished processing for user id:  741
# finished processing for user id:  742
# finished processing for user id:  743
# finished processing for user id:  744
# finished processing for user id:  745
# finished processing for user id:  746
# finished processing for user id:  747
# finished processing for user id:  748
# finished processing for user id:  749
# finished processing for user id:  750
# finished processing for user id:  751
# finished processing for user id:  752
# finished processing for user id:  753
# finished processing for user id:  754
# finished processing for user id:  755
# finished processing for user id:  756
# finished processing for user id:  757
# finished processing for user id:  758
# finished processing for user id:  759
# finished processing for user id:  760
# finished processing for user id:  761
# finished processing for user id:  762
# finished processing for user id:  763
# finished processing for user id:  764
# finished processing for user id:  765
# finished processing for user id:  766
# finished processing for user id:  767
# finished processing for user id:  768
# finished processing for user id:  769
# finished processing for user id:  770
# finished processing for user id:  771
# finished processing for user id:  772
# finished processing for user id:  773
# finished processing for user id:  774
# finished processing for user id:  775
# finished processing for user id:  776
# finished processing for user id:  777
# finished processing for user id:  778
# finished processing for user id:  779
# finished processing for user id:  780
# finished processing for user id:  781
# finished processing for user id:  782
# finished processing for user id:  783
# finished processing for user id:  784
# finished processing for user id:  785
# finished processing for user id:  786
# finished processing for user id:  787
# finished processing for user id:  788
# finished processing for user id:  789
# finished processing for user id:  790
# finished processing for user id:  791
# finished processing for user id:  792
# finished processing for user id:  793
# finished processing for user id:  794
# finished processing for user id:  795
# finished processing for user id:  796
# finished processing for user id:  797
# finished processing for user id:  798
# finished processing for user id:  799
# finished processing for user id:  800
# finished processing for user id:  801
# finished processing for user id:  802
# finished processing for user id:  803
# finished processing for user id:  804
# finished processing for user id:  805
# finished processing for user id:  806
# finished processing for user id:  807
# finished processing for user id:  808
# finished processing for user id:  809
# finished processing for user id:  810
# finished processing for user id:  811
# finished processing for user id:  812
# finished processing for user id:  813
# finished processing for user id:  814
# finished processing for user id:  815
# finished processing for user id:  816
# finished processing for user id:  817
# finished processing for user id:  818
# finished processing for user id:  819
# finished processing for user id:  820
# finished processing for user id:  821
# finished processing for user id:  822
# finished processing for user id:  823
# finished processing for user id:  824
# finished processing for user id:  825
# finished processing for user id:  826
# finished processing for user id:  827
# finished processing for user id:  828
# finished processing for user id:  829
# finished processing for user id:  830
# finished processing for user id:  831
# finished processing for user id:  832
# finished processing for user id:  833
# finished processing for user id:  834
# finished processing for user id:  835
# finished processing for user id:  836
# finished processing for user id:  837
# finished processing for user id:  838
# finished processing for user id:  839
# finished processing for user id:  840
# finished processing for user id:  841
# finished processing for user id:  842
# finished processing for user id:  843
# finished processing for user id:  844
# finished processing for user id:  845
# finished processing for user id:  846
# finished processing for user id:  847
# finished processing for user id:  848
# finished processing for user id:  849
# finished processing for user id:  850
# finished processing for user id:  851
# finished processing for user id:  852
# finished processing for user id:  853
# finished processing for user id:  854
# finished processing for user id:  855
# finished processing for user id:  856
# finished processing for user id:  857
# finished processing for user id:  858
# finished processing for user id:  859
# finished processing for user id:  860
# finished processing for user id:  861
# finished processing for user id:  862
# finished processing for user id:  863
# finished processing for user id:  864
# finished processing for user id:  865
# finished processing for user id:  866
# finished processing for user id:  867
# finished processing for user id:  868
# finished processing for user id:  869
# finished processing for user id:  870
# finished processing for user id:  871
# finished processing for user id:  872
# finished processing for user id:  873
# finished processing for user id:  874
# finished processing for user id:  875
# finished processing for user id:  876
# finished processing for user id:  877
# finished processing for user id:  878
# finished processing for user id:  879
# finished processing for user id:  880
# finished processing for user id:  881
# finished processing for user id:  882
# finished processing for user id:  883
# finished processing for user id:  884
# finished processing for user id:  885
# finished processing for user id:  886
# finished processing for user id:  887
# finished processing for user id:  888
# finished processing for user id:  889
# finished processing for user id:  890
# finished processing for user id:  891
# finished processing for user id:  892
# finished processing for user id:  893
# finished processing for user id:  894
# finished processing for user id:  895
# finished processing for user id:  896
# finished processing for user id:  897
# finished processing for user id:  898
# finished processing for user id:  899
# finished processing for user id:  900
# finished processing for user id:  901
# finished processing for user id:  902
# finished processing for user id:  903
# finished processing for user id:  904
# finished processing for user id:  905
# finished processing for user id:  906
# finished processing for user id:  907
# finished processing for user id:  908
# finished processing for user id:  909
# finished processing for user id:  910
# finished processing for user id:  911
# finished processing for user id:  912
# finished processing for user id:  913
# finished processing for user id:  914
# finished processing for user id:  915
# finished processing for user id:  916
# finished processing for user id:  917
# finished processing for user id:  918
# finished processing for user id:  919
# finished processing for user id:  920
# finished processing for user id:  921
# finished processing for user id:  922
# finished processing for user id:  923
# finished processing for user id:  924
# finished processing for user id:  925
# finished processing for user id:  926
# finished processing for user id:  927
# finished processing for user id:  928
# finished processing for user id:  929
# finished processing for user id:  930
# finished processing for user id:  931
# finished processing for user id:  932
# finished processing for user id:  933
# finished processing for user id:  934
# finished processing for user id:  935
# finished processing for user id:  936
# finished processing for user id:  937
# finished processing for user id:  938
# finished processing for user id:  939
# finished processing for user id:  940
# finished processing for user id:  941
# finished processing for user id:  942
# finished processing for user id:  943
# finished processing for user id:  944
# finished processing for user id:  945
# finished processing for user id:  946
# finished processing for user id:  947
# finished processing for user id:  948
# finished processing for user id:  949
# finished processing for user id:  950
# finished processing for user id:  951
# finished processing for user id:  952
# finished processing for user id:  953
# finished processing for user id:  954
# finished processing for user id:  955
# finished processing for user id:  956
# finished processing for user id:  957
# finished processing for user id:  958
# finished processing for user id:  959
# finished processing for user id:  960
# finished processing for user id:  961
# finished processing for user id:  962
# finished processing for user id:  963
# finished processing for user id:  964
# finished processing for user id:  965
# finished processing for user id:  966
# finished processing for user id:  967
# finished processing for user id:  968
# finished processing for user id:  969
# finished processing for user id:  970
# finished processing for user id:  971
# finished processing for user id:  972
# finished processing for user id:  973
# finished processing for user id:  974
# finished processing for user id:  975
# finished processing for user id:  976
# finished processing for user id:  977
# finished processing for user id:  978
# finished processing for user id:  979
# finished processing for user id:  980
# finished processing for user id:  981
# finished processing for user id:  982
# finished processing for user id:  983
# finished processing for user id:  984
# finished processing for user id:  985
# finished processing for user id:  986
# finished processing for user id:  987
# finished processing for user id:  988
# finished processing for user id:  989
# finished processing for user id:  990
# finished processing for user id:  991
# finished processing for user id:  992
# finished processing for user id:  993
# finished processing for user id:  994
# finished processing for user id:  995
# finished processing for user id:  996
# finished processing for user id:  997
# finished processing for user id:  998
# finished processing for user id:  999

# %%
def predict(i,m):
    numerator = 0
    denominator = 0
    for neg_w,j in neighbors[i]:
        try: 
            numerator += -neg_w * deviations[j][m]
            denominator += abs(neg_w)
        except KeyError: # user j may not have rated movie m so it migh not exist in deviations , instead pf looking up twice throgh exception
            pass
        
    if denominator == 0:
        prediction = averages[i]
    else:
        prediction = numerator / denominator + averages[i]
    prediction = min(5,prediction)
    prediction = max(0.5,prediction)
    return prediction

# %%
train_predictions = []
train_targets = []

for (i,m),target in user_movie2rating.items():
    prediction = predict(i,m)
    train_predictions.append(prediction)
    train_targets.append(target)

# %%
test_predictions = []
test_targets = []

for (i,m),target in user_movie2rating_test.items():
    prediction = predict(i,m)
    test_predictions.append(prediction)
    test_targets.append(target)

# %%
def mse(p,t): # for accuracy
    p = np.array(p)
    t = np.array(t)
    return np.mean((p-t)**2)

# %%
print('train mse: ',mse(train_predictions,train_targets))
print('train mse: ',mse(test_predictions,test_targets))
# Out:
# train mse:  0.4613057521837811
# train mse:  0.5960859832624089

# %% [markdown]
# <h2>Item-Item Collaborative Filtering</h2>

# %%
with open('user2movie.json','rb') as f:
    user2movie = pickle.load(f)
    
with open('movie2user.json','rb') as f:
    movie2user = pickle.load(f)
    
with open('user_movie2rating.json','rb') as f:
    user_movie2rating =  pickle.load(f)
    
with open('user_movie2rating_test.json','rb') as f:
    user_movie2rating_test =  pickle.load(f)

# %%
N = np.max(list(user2movie.keys()))+1
# some movies may appear in test but not in train
# unlikely to occur in user
m1 = np.max(list(movie2user.keys()))
m2 = np.max([m for(u,m),r in user_movie2rating_test.items()])
M = max(m1,m2) + 1

# %%
K = 20 # number of neighbours to consider
limit = 5 # number of movies users must have in common to consider
averages = [] # each user's average rating
deviations = [] # each user's deviation
neighbors = [] # each element is a list of neighbours for each user

# %%
for i in range(M): # now i is movie , just assume movies became users and vice versa
    users_i = movie2user[i]
    users_i_set = set(users_i)
    
    # calculate average and deviation
    ratings_i = {user:user_movie2rating[(user,i)] for user in users_i} # rating for each movie
    avg_i = np.mean(list(ratings_i.values())) # average across all movies
    dev_i = {user:(rating-avg_i) for user,rating in ratings_i.items()} # deviation for each movie
    dev_i_values = np.array(list(dev_i.values()))
    sigma_i = np.sqrt(dev_i_values.dot(dev_i_values))
    
    # calculate correlation coeffecient
    averages.append(avg_i)
    deviations.append(dev_i)
    
    sl = SortedList()
    for j in range(M):
        if j != i: # dont include this i th user
            users_j = movie2user[j]
            users_j_set = set(users_j)
            common_movies = (users_i_set & users_j_set) # intersection
            if len(common_movies) > limit:
                # calculate  avg and ddeviation
                ratings_j = {user:user_movie2rating[(user,j)] for user in users_j} # rating for each movie
                avg_j = np.mean(list(ratings_j.values())) # average across all movies
                dev_j = {user:(rating-avg_j) for user,rating in ratings_j.items()} # deviation for each movie
                dev_j_values = np.array(list(dev_j.values()))
                sigma_j = np.sqrt(dev_j_values.dot(dev_j_values))
                
                # calculate correlation coffecient
                numerator = sum(dev_i[m]*dev_j[m] for m in common_movies)
                w_ij = numerator / (sigma_i * sigma_j)
                sl.add((-w_ij,j)) # list sorts ascendingly , to keep highest first negate
                if len(sl) > K:
                    del sl[-1]
    neighbors.append(sl)
    print('finished processing for movie id: ',i)
# Out:
# finished processing for movie id:  0
# finished processing for movie id:  1
# finished processing for movie id:  2
# finished processing for movie id:  3
# finished processing for movie id:  4
# finished processing for movie id:  5
# finished processing for movie id:  6
# finished processing for movie id:  7
# finished processing for movie id:  8
# finished processing for movie id:  9
# finished processing for movie id:  10
# finished processing for movie id:  11
# finished processing for movie id:  12
# finished processing for movie id:  13
# finished processing for movie id:  14
# finished processing for movie id:  15
# finished processing for movie id:  16
# finished processing for movie id:  17
# finished processing for movie id:  18
# finished processing for movie id:  19
# finished processing for movie id:  20
# finished processing for movie id:  21
# finished processing for movie id:  22
# finished processing for movie id:  23
# finished processing for movie id:  24
# finished processing for movie id:  25
# finished processing for movie id:  26
# finished processing for movie id:  27
# finished processing for movie id:  28
# finished processing for movie id:  29
# finished processing for movie id:  30
# finished processing for movie id:  31
# finished processing for movie id:  32
# finished processing for movie id:  33
# finished processing for movie id:  34
# finished processing for movie id:  35
# finished processing for movie id:  36
# finished processing for movie id:  37
# finished processing for movie id:  38
# finished processing for movie id:  39
# finished processing for movie id:  40
# finished processing for movie id:  41
# finished processing for movie id:  42
# finished processing for movie id:  43
# finished processing for movie id:  44
# finished processing for movie id:  45
# finished processing for movie id:  46
# finished processing for movie id:  47
# finished processing for movie id:  48
# finished processing for movie id:  49
# finished processing for movie id:  50
# finished processing for movie id:  51
# finished processing for movie id:  52
# finished processing for movie id:  53
# finished processing for movie id:  54
# finished processing for movie id:  55
# finished processing for movie id:  56
# finished processing for movie id:  57
# finished processing for movie id:  58
# finished processing for movie id:  59
# finished processing for movie id:  60
# finished processing for movie id:  61
# finished processing for movie id:  62
# finished processing for movie id:  63
# finished processing for movie id:  64
# finished processing for movie id:  65
# finished processing for movie id:  66
# finished processing for movie id:  67
# finished processing for movie id:  68
# finished processing for movie id:  69
# finished processing for movie id:  70
# finished processing for movie id:  71
# finished processing for movie id:  72
# finished processing for movie id:  73
# finished processing for movie id:  74
# finished processing for movie id:  75
# finished processing for movie id:  76
# finished processing for movie id:  77
# finished processing for movie id:  78
# finished processing for movie id:  79
# finished processing for movie id:  80
# finished processing for movie id:  81
# finished processing for movie id:  82
# finished processing for movie id:  83
# finished processing for movie id:  84
# finished processing for movie id:  85
# finished processing for movie id:  86
# finished processing for movie id:  87
# finished processing for movie id:  88
# finished processing for movie id:  89
# finished processing for movie id:  90
# finished processing for movie id:  91
# finished processing for movie id:  92
# finished processing for movie id:  93
# finished processing for movie id:  94
# finished processing for movie id:  95
# finished processing for movie id:  96
# finished processing for movie id:  97
# finished processing for movie id:  98
# finished processing for movie id:  99
# finished processing for movie id:  100
# finished processing for movie id:  101
# finished processing for movie id:  102
# finished processing for movie id:  103
# finished processing for movie id:  104
# finished processing for movie id:  105
# finished processing for movie id:  106
# finished processing for movie id:  107
# finished processing for movie id:  108
# finished processing for movie id:  109
# finished processing for movie id:  110
# finished processing for movie id:  111
# finished processing for movie id:  112
# finished processing for movie id:  113
# finished processing for movie id:  114
# finished processing for movie id:  115
# finished processing for movie id:  116
# finished processing for movie id:  117
# finished processing for movie id:  118
# finished processing for movie id:  119
# finished processing for movie id:  120
# finished processing for movie id:  121
# finished processing for movie id:  122
# finished processing for movie id:  123
# finished processing for movie id:  124
# finished processing for movie id:  125
# finished processing for movie id:  126
# finished processing for movie id:  127
# finished processing for movie id:  128
# finished processing for movie id:  129
# finished processing for movie id:  130
# finished processing for movie id:  131
# finished processing for movie id:  132
# finished processing for movie id:  133
# finished processing for movie id:  134
# finished processing for movie id:  135
# finished processing for movie id:  136
# finished processing for movie id:  137
# finished processing for movie id:  138
# finished processing for movie id:  139
# finished processing for movie id:  140
# finished processing for movie id:  141
# finished processing for movie id:  142
# finished processing for movie id:  143
# finished processing for movie id:  144
# finished processing for movie id:  145
# finished processing for movie id:  146
# finished processing for movie id:  147
# finished processing for movie id:  148
# finished processing for movie id:  149
# finished processing for movie id:  150
# finished processing for movie id:  151
# finished processing for movie id:  152
# finished processing for movie id:  153
# finished processing for movie id:  154
# finished processing for movie id:  155
# finished processing for movie id:  156
# finished processing for movie id:  157
# finished processing for movie id:  158
# finished processing for movie id:  159
# finished processing for movie id:  160
# finished processing for movie id:  161
# finished processing for movie id:  162
# finished processing for movie id:  163
# finished processing for movie id:  164
# finished processing for movie id:  165
# finished processing for movie id:  166
# finished processing for movie id:  167
# finished processing for movie id:  168
# finished processing for movie id:  169
# finished processing for movie id:  170
# finished processing for movie id:  171
# finished processing for movie id:  172
# finished processing for movie id:  173
# finished processing for movie id:  174
# finished processing for movie id:  175
# finished processing for movie id:  176
# finished processing for movie id:  177
# finished processing for movie id:  178
# finished processing for movie id:  179
# finished processing for movie id:  180
# finished processing for movie id:  181
# finished processing for movie id:  182
# finished processing for movie id:  183
# finished processing for movie id:  184
# finished processing for movie id:  185
# finished processing for movie id:  186
# finished processing for movie id:  187
# finished processing for movie id:  188
# finished processing for movie id:  189
# finished processing for movie id:  190
# finished processing for movie id:  191
# finished processing for movie id:  192
# finished processing for movie id:  193
# finished processing for movie id:  194
# finished processing for movie id:  195
# finished processing for movie id:  196
# finished processing for movie id:  197
# finished processing for movie id:  198
# finished processing for movie id:  199

# %%
def predict(i,u):
    numerator = 0
    denominator = 0
    for neg_w,j in neighbors[i]:
        try: 
            numerator += -neg_w * deviations[j][u]
            denominator += abs(neg_w)
        except KeyError: # user j may not have rated movie m so it migh not exist in deviations , instead pf looking up twice throgh exception
            pass
        
    if denominator == 0:
        prediction = averages[i]
    else:
        prediction = numerator / denominator + averages[i]
    prediction = min(5,prediction)
    prediction = max(0.5,prediction)
    return prediction

# %%
train_predictions = []
train_targets = []

for (i,m),target in user_movie2rating.items():
    prediction = predict(m,i) # same function just switch inputs
    train_predictions.append(prediction)
    train_targets.append(target)

# %%
test_predictions = []
test_targets = []

for (i,m),target in user_movie2rating_test.items():
    prediction = predict(m,i)
    test_predictions.append(prediction)
    test_targets.append(target)

# %%
def mse(p,t): # for accuracy
    p = np.array(p)
    t = np.array(t)
    return np.mean((p-t)**2)

# %%
print('train mse: ',mse(train_predictions,train_targets))
print('train mse: ',mse(test_predictions,test_targets))
# Out:
# train mse:  0.5083151016169266
# train mse:  0.5500312185708748
